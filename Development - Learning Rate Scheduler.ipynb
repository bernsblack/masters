# %%
import numpy as np
import plotly.graph_objects as go
import pandas as pd

# %%
import plotly.graph_objects as go
def plot(**kwargs):
    traces = []
    for k, v in kwargs.items():
        traces.append(
            go.Scatter(y=v, name=k)
        )
    return go.Figure(
        traces
    )

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.neural_network import MLPClassifier

# %%
X,y = load_iris(return_X_y=True)

# %%
mlp = MLPClassifier((100,100), max_iter=10)

# %%
mlp.fit(X,y)
# Out:
# /home/bernard/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=10)

# %%
y_pred = mlp.predict(X)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y,y_pred)
# Out:
# 0.7466666666666667

# %%
import torch
from torch import nn
from torch import optim
from torch.optim import lr_scheduler

# %%
X,y = load_iris(return_X_y=True)
X, y = torch.FloatTensor(X), torch.LongTensor(y)

# %%
torch.manual_seed(11)

n,d = X.shape
LR = 5e-2
model = nn.Sequential(nn.Linear(d,10),nn.ReLU(), nn.Linear(10,3))
linear = model[0]
optimizer = optim.Adam(model.parameters(), lr=LR)
# scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer=optimizer, T_max=100)
# scheduler = None
# scheduler = lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=100)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=max_epochs//3, gamma=0.2, last_epoch=-1) 


loss_fn = nn.CrossEntropyLoss()

weight_grad_sum = []
losses = []
max_epochs = 1000
for epoch in range(max_epochs):
    optimizer.zero_grad()
    out =  model.forward(X)
    loss = loss_fn(out, y)
    loss.backward()
    optimizer.step()
    weight_grad_sum.append(torch.sum(linear.weight.grad))
    losses.append(loss.item())
    if scheduler:
        scheduler.step()
        
#     print(f"scheduler lr: {scheduler.get_lr()[0]:.5f}")
#     print(f"optimizer lr: {optimizer.param_groups[0]['lr']:.5f}")
#     print()
    
plot(losses=losses,weight_grad_sum=weight_grad_sum)
# Out:
# <div>
#
#
#             <div id="fd1ae47a-42d0-41f7-a9d4-574a8dcaeaa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fd1ae47a-42d0-41f7-a9d4-574a8dcaeaa7")) {
#                     Plotly.newPlot(
#                         'fd1ae47a-42d0-41f7-a9d4-574a8dcaeaa7',
# ...

# %%
accuracy_score(y,y_pred)
