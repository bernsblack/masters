# %% [markdown]
# ## Visualize Generated Data
# Use this notebook as a centre point where you can select a generated data and visualize it easily

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils.plots import *
import matplotlib as mpl
from utils import get_data_sub_paths, by_ref

# %%
# set plots to look like latex
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'

# %%
data_sub_paths = get_data_sub_paths()
data_sub_paths
# Out:
# ['T168H-X1275M-Y1320M_2001-01-04_2019-01-03_#1f1',
#  'T24H-X1700M-Y1760M_2014-01-01_2019-01-01_#828',
#  'T1H-X2550M-Y2640M_2014-01-01_2019-01-01_#7ce',
#  'T24H-X255M-Y220M_2012-01-01_2019-01-01_#c97',
#  'Totals_T1H_2014-01-01_2019-01-01_LAT41.641_42.024_LON-87.821_-87.525',
#  'T24H-X850M-Y880M_2012-01-01_2019-01-01_#826',
#  'Totals_T24H_2001-01-01_2019-01-02_LAT41.641_42.024_LON-87.821_-87.525',
#  'T24H-X425M-Y440M_2012-01-01_2019-01-01_#827',
#  'T24H-X1275M-Y1320M_2012-01-01_2019-01-01_#939',
#  'Totals_T168H_2001-01-04_2019-01-10_LAT41.641_42.024_LON-87.821_-87.525']

# %%
data_sub_path = by_ref("826")[0]
data_sub_path
# Out:
# 'T24H-X850M-Y880M_2012-01-01_2019-01-01_#826'

# %%
folder = f"./data/processed/{data_sub_path}/"
folder
# Out:
# './data/processed/T24H-X850M-Y880M_2012-01-01_2019-01-01_#826/'

# %%
zip_file = np.load(folder + "generated_data.npz")
crime_types_grids = zip_file["crime_types_grids"]
crime_grids = zip_file["crime_grids"]
demog_grid = zip_file["demog_grid"]
street_grid = zip_file["street_grid"]
time_vectors = zip_file["time_vectors"]
x_range = zip_file["x_range"]
y_range = zip_file["y_range"]
t_range = pd.read_pickle(folder + "t_range.pkl")

# %%
# cap = 25
# crime_grids[crime_grids > cap] = cap

# %%
im(np.mean(crime_grids, axis=0)[0])
im(np.max(crime_grids, axis=0)[0])
plot_dist(crime_grids)
